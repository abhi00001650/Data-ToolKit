# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings("ignore")

# %%
#WHY?? SEABORN ?? >>> More attractive plots >> more options of statistical plots

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('planets') #syntax to load the dataset
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info
# Out:
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#numerical data plotting
#relplot has options of plotting both categorical and numerical ata
#relplot>> how the relationship betwen 2 variables

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#how tip is variying with total_bill >> scatterplot / bydefault relplot make scatterplot

sns.relplot(x = 'total_bill' , y = 'tip' , data = df)# relationship between 2 variables by default it gives scatterplot, kind = line

#as total bill increases tip increases

# %%
sns.relplot(x = 'total_bill' , y = 'tip' , data = df , kind = 'line')

# %%
#Distinguish between smoker and non smoker

sns.relplot(x = 'total_bill' , y = 'tip' , data = df , hue = 'smoker' )
#insight >>> customer who smoked gave the highest tip

# %%
sns.relplot(x = 'total_bill' , y = 'tip' , data = df , hue = 'size'  )#hue gives different color set/contrast

# %%
sns.relplot(x = 'total_bill' , y = 'tip' , data = df , style = 'size' , hue = 'size')

# %%
sns.relplot(x = 'total_bill' , y = 'tip' , data = df , style = 'smoker' , hue = 'time')

# %%
#relplot >> to make a  line plot >> generating a data 
# line plot >> to understand the trendss in data / time column/sequence is generally invilved

# %%
time = np.arange(500)
value = np.random.randn(500).cumsum()
df = pd.DataFrame({'time' : time , 'value': value})
df
# Out:
#      time      value
# 0       0  -0.307476
# 1       1   0.293282
# 2       2  -0.205425
# 3       3   1.461259
# 4       4   2.309007
# ..    ...        ...
# 495   495  19.125602
# 496   496  19.905749
# 497   497  21.605677
# 498   498  21.629985
# 499   499  20.116839
#
# [500 rows x 2 columns]

# %%
sns.relplot( x = 'time' , y = 'value' , kind = 'line' , data = df , sort = True)

# %%
df = sns.load_dataset('fmri')

# %%
sns.relplot( x = 'timepoint' , y = 'signal' , kind = 'line' , data = df)

# %%
sns.relplot( x = 'timepoint' , y = 'signal' , kind = 'line' , data = df , ci = 'sd')

# %%
sns.relplot( x = 'timepoint' , y = 'signal' , estimator = None , kind = 'line' , data = df , ci = 'sd')

# %%
sns.relplot( x = 'timepoint' , y = 'signal' , estimator = None , kind = 'line' , data = df )

# %%
sns.relplot( x = 'timepoint' , y = 'signal' ,  kind = 'line' , data = df , hue = 'event' )

# %%
sns.relplot( x = 'timepoint' , y = 'signal' ,  kind = 'line' , data = df , hue = 'event' , style = 'region' )

# %%
#REMOVES THE DASHES IN LINE CHART , dashes = False
sns.relplot( x = 'timepoint' , y = 'signal' ,  kind = 'line' , data = df , hue = 'event' , style = 'region' , dashes = False)

# %%
sns.relplot( x = 'timepoint' , y = 'signal' ,  kind = 'line' , data = df , hue = 'event' , style = 'region' , markers = True)

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#2 sub plots based on a column
sns.relplot( x = 'total_bill' , y = 'tip' , hue = 'smoker' , data = tips , col = 'time')

# %%
#2 sub plots based on a column
sns.relplot( x = 'total_bill' , y = 'tip' , hue = 'smoker' , data = tips , col = 'size')

# %%
#categorical data plots
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
#plot between data and total bill , day is a categorical column
sns.catplot(x = 'day' , y = 'total_bill' , data = tips)

# %%
#insights >> many people arrive on weekends as compared to weekdays
#in catplot few datapoints are overlapping >> to see it separately use swarm  plot 
sns.catplot(x = 'day' , y = 'total_bill' , data = tips , kind = 'swarm')

# %%
#boxplot >> to see outliers
sns.catplot(x = 'day' , y = 'total_bill' , data = tips , kind = 'box' , hue = 'day')

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = tips , hue = 'day' , kind = 'violin' )

# %%
sns.catplot(x = 'day' , y = 'total_bill' , data = tips , kind = 'boxen' , hue = 'day') # boxen>> made from box plot itself

# %%
sns.barplot(x = 'day' , y = 'total_bill' , data = tips , hue = 'day')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#univariate
sns.jointplot(x = tips.total_bill , y = tips.tip) # draw a plot of 2 variables with distribution >> bivariate plot

# %%
#joint plot >> understand relationship and also distribution of 2 variables

sns.jointplot( x = tips.total_bill, y = tips.tip , kind = 'reg')

# %%
sns.jointplot( x = tips.total_bill, y = tips.tip , kind = 'hex')

# %%
sns.jointplot( x = tips.total_bill, y = tips.tip , kind = 'kde')

# %%
sns.pairplot(tips) # make scatter plots with resspect to all numerical columns

# %%
sns.pairplot(tips , hue = 'smoker')

# %%
sns.pairplot(tips , hue = 'smoker' , palette = 'coolwarm')

# %%
sns.pairplot(tips , hue = 'smoker' , palette = 'Set2')

# %%
#boxplot
sns.boxplot(x = 'day' , y= 'total_bill' , data = tips , palette = 'rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#boxplot
sns.boxplot(data = tips , palette = 'rainbow' , orient = 'h')
# Out:
# <Axes: >

# %%
df1 = tips[['total_bill' , 'tip' , 'size']]

# %%
df1
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
#correlation >> how x and y varies acccording to changes in each
df1.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#heatmap>> value encoded with different colour sets
sns.heatmap(df1.corr() , cmap = 'coolwarm' , annot = True)
# Out:
# <Axes: >

# %%
df
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
df = sns.load_dataset('tips')

# %%
sns.countplot(x = 'sex' , data = df , hue = 'sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill' , y = 'tip' , data = df , hue = 'smoker')

# %%
sns.lmplot(x = 'total_bill' , y = 'tip' , data = df , hue = 'smoker' , height = 15)

# %%
sns.lmplot(x = 'total_bill' , y = 'tip' , data = df , hue = 'smoker' , height = 15 , aspect = 1)
